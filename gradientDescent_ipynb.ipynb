# %% [markdown]
# <a href="https://colab.research.google.com/github/Molly-12/Base-class/blob/main/gradientDescent_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
data=[]
for i in range(100):
  x=np.random.uniform(-10,10)
  eps=np.random.normal(0,0.01)
  y=1.477 *x +0.089+eps
  data.append([x,y])
data=np.array(data)
print(data)
# Out:
# [[  8.88822422  13.21265236]
#  [ -2.63077809  -3.78898334]
#  [ -7.5279144  -11.02544147]
#  [  4.17568397   6.25860155]
#  [  3.23815566   4.86282508]
#  [ -7.23900127 -10.61106067]
#  [  4.21079834   6.29498876]
#  [  5.95839626   8.88384528]
#  [ -8.15206343 -11.94267917]
#  [ -6.27966899  -9.18837693]
#  [ -2.46754355  -3.54628268]
#  [  7.59766278  11.30575437]
#  [ -0.9517159   -1.30719021]
#  [  0.54837555   0.9052284 ]
#  [ -1.82543574  -2.61650237]
#  [  7.16669675  10.68511983]
#  [  7.82047944  11.64289673]
#  [ -0.06587993  -0.02573833]
#  [  2.59540401   3.9319576 ]
#  [ -7.39984561 -10.8385219 ]
#  [ -0.20382118  -0.19499312]
#  [  2.89971837   4.37513702]
#  [ -5.53819151  -8.10343405]
#  [ -3.32818236  -4.82101533]
#  [ -5.41288785  -7.9042381 ]
#  [ -9.52235345 -13.97974154]
#  [ -2.57629095  -3.71260931]
#  [ -2.22539416  -3.19394705]
#  [  3.81101909   5.72236293]
#  [  9.37492654  13.93510793]
#  [  4.84740967   7.25871733]
#  [ -9.61282257 -14.09819063]
# ...

# %%
#calculate mean squared error
def mse(b,w,points):
  totalError=0
  for i in range(0,len(points)):
    x=points[i,0]
    y=points[i,1]
    totalError+=(y-(w*x+b))**2
  return totalError/float(len(points))
